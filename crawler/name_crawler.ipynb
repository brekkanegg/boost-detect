# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib import parse
import random
from html.parser import HTMLParser
from tqdm import *
from time import *
import re

# %%
for i in range(1,3):
    print(i)
# Out:
# 1
# 2

# %%
txt = open('summoners.txt', 'w')
#     for i in tqdm(range(3952, 4272)):
# for i in tqdm(range(3952, 4272)): #platinum_5 0LP
# for i in tqdm(range(876, 4272)): #platinum
for i in tqdm(range(12489, 13958)): #gold_5 0LP
    url = 'http://lol.inven.co.kr/dataninfo/ladder/index.php?pg=' + str(i) ii
    r = urlopen(url).read()
    soup = BeautifulSoup(r, "html.parser")

    temp = soup.find_all('a')
#     aa = soup.find_all('a', _class="sth")
    t = str(temp).replace(" ", "")
    summoner_names = re.findall(r';">(\w+)</a>,<ahref="http://lol.inven.co.kr', t)
    summoner_names = "\n".join(summoner_names)

    with open('summoners.txt', 'a') as txt:
        txt.write(summoner_names)
        txt.write('\n')
# Out:
# 100%|██████████| 1469/1469 [20:33<00:00,  1.07it/s]

# %%
txt = open('summoners.txt', 'w')
# txt.writelines(summoner_names+'\n')
txt.write(summoner_names)
# Out:
# 421

# %%
t
summoner_names = re.findall(r';">(\w+)</a>,<ahref="http://lol.inven.co.kr', t)
summoner_names = "\n".join(summoner_names)
summoner_names
# Out:
# '학식먹을나이\nqweqwascxxzsdxz\nBl디디\nYMzhongdan\nLongzhuCuzz\nClid\n분노의질주더세븐\niG루키이\nLASTDANCE7\nGimGoon\n긴간히\n콜라로리필\nHushenHuya\n박투신\n빈동고호경송\n커피물조절장인\n삼겹살목살살치살\n삼성갤럭시봉순\n연애안하면서롤함\n쪼렙이다말로하자\n열심히잘하자아\nUnidentifled\n내꿈은팟수\nxunduiWXlze3919\n가좌고미율치\n수적석천\n삼성갤럭시서포터\nbbqTempt\n아이지Rook1E\nAfreecaKuro\nSeroum\n봄나무꿈\n탑그라혐오증환자\n삼성갤럭시하루\n이도류\nJacen\n케찹계란밥\nFotune\nRurucia\nShiroNekol\nreMemberMistake\n깊이반성하며\nAfreecaKramer\nbianyishishishou\n전로협\n마산가자\nLehends\nDANGgoong\nMVPIan\n취소'

# %%
with open('summoners.txt', 'a') as txt:
    txt.write('\n')
    txt.write(summoner_names)

# %%
# re.findall()

# %%
summoner_names
# Out:
# '학식먹을나이\nqweqwascxxzsdxz\nBl디디\nYMzhongdan\nLongzhuCuzz\nClid\n분노의질주더세븐\niG루키이\nLASTDANCE7\nGimGoon\n긴간히\n콜라로리필\nHushenHuya\n박투신\n빈동고호경송\n커피물조절장인\n삼겹살목살살치살\n삼성갤럭시봉순\n연애안하면서롤함\n쪼렙이다말로하자\n열심히잘하자아\nUnidentifled\n내꿈은팟수\nxunduiWXlze3919\n가좌고미율치\n수적석천\n삼성갤럭시서포터\nbbqTempt\n아이지Rook1E\nAfreecaKuro\nSeroum\n봄나무꿈\n탑그라혐오증환자\n삼성갤럭시하루\n이도류\nJacen\n케찹계란밥\nFotune\nRurucia\nShiroNekol\nreMemberMistake\n깊이반성하며\nAfreecaKramer\nbianyishishishou\n전로협\n마산가자\nLehends\nDANGgoong\nMVPIan\n취소'

# %%
t = str(temp).replace(" ", "")
summoner_names = re.findall(r';">(\w+)</a>,<ahref="http://lol.inven.co.kr', t)
summoner_names
# Out:
# ['학식먹을나이',
#  'qweqwascxxzsdxz',
#  'Bl디디',
#  'YMzhongdan',
#  'LongzhuCuzz',
#  'Clid',
#  '분노의질주더세븐',
#  'iG루키이',
#  'LASTDANCE7',
#  'GimGoon',
#  '긴간히',
#  '콜라로리필',
#  'HushenHuya',
#  '박투신',
#  '빈동고호경송',
#  '커피물조절장인',
#  '삼겹살목살살치살',
#  '삼성갤럭시봉순',
#  '연애안하면서롤함',
#  '쪼렙이다말로하자',
#  '열심히잘하자아',
#  'Unidentifled',
#  '내꿈은팟수',
#  'xunduiWXlze3919',
#  '가좌고미율치',
#  '수적석천',
#  '삼성갤럭시서포터',
#  'bbqTempt',
#  '아이지Rook1E',
#  'AfreecaKuro',
#  'Seroum',
#  '봄나무꿈',
#  '탑그라혐오증환자',
#  '삼성갤럭시하루',
#  '이도류',
#  'Jacen',
#  '케찹계란밥',
#  'Fotune',
#  'Rurucia',
#  'ShiroNekol',
#  'reMemberMistake',
#  '깊이반성하며',
#  'AfreecaKramer',
#  'bianyishishishou',
#  '전로협',
#  '마산가자',
#  'Lehends',
#  'DANGgoong',
#  'MVPIan',
#  '취소']

# %%
print(soup.prettify()[120000-500:130000])
# Out:
# ank">
#                -
#               </div>
#              </td>
#             </tr>
#            </table>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# <td>
#  <a href="http://lol.inven.co.kr/dataninfo/player/list.php?sname=%ED%95%99%EC%8B%9D%EB%A8%B9%EC%9D%84%EB%82%98%EC%9D%B4" onmouseout="LOL.Db.PlayerLayer.hide('s52450166');" onmouseover="LOL.Db.PlayerLayer.show('s52450166');">
#   학식먹을나이
#  </a>
# </td>
# <td>
# </td>
# <td class="league">
#  챌린저 1
# </td>
# <td class="win">
#  307
# </td>
# <td class="lose">
#  195
# </td>
# <td>
#  1325
# </td>
# <!-- <td>86325</td> -->
# <td class="etc">
# </td>
# <tr class="double">
#  <td>
#   <div class="crank">
#    2
#   </div>
#   <div class="orank">
#    -
#   </div>
#  </td>
# </tr>
# <td>
# ...
